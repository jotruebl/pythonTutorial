# %%
# imports
import pandas as pd
import plotly.express as px
from plotly.subplots import make_subplots
pd.set_option('display.max_columns', 999)
import plotly.graph_objs as go
import scipy.stats as stats
import numpy as np
import math

# %%
data = pd.DataFrame()
data['diameter'] = np.arange(1E-9,1E-6,1E-9) # m - diameter of a pure liquid droplet 
sigma = .072 # J/m^2 
M = .01802 # g/mol
rho = 1000 # kg/m^3
R = 8.314 # J/(K*mol)
T = 293.15 # kelvin

# %% [markdown]
# # Kelvin Effect

# %%
data['S']=np.exp((4*sigma*M)/(rho*R*T*data['diameter']))

# %% [markdown]
# # $ e_s(r) = e_s(\infty) exp(\frac{2\sigma}{RT\rho r})$
#
# # $ A= \frac{2\sigma}{RT\rho }$

# %%
fig=px.line(data, x='diameter', y='S')
fig.update_xaxes(type='log')
# Out:
# <div>
#
#
#             <div id="89609f44-3089-4560-8ba2-8fbcab8a1a5c" class="plotly-graph-div" style="height:600px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("89609f44-3089-4560-8ba2-8fbcab8a1a5c")) {
#                     Plotly.newPlot(
#                         '89609f44-3089-4560-8ba2-8fbcab8a1a5c',
#                         [{"hoverlabel": {"namelength": 0}, "hovertemplate": "diameter=%{x}<br>S=%{y}", "legendgroup": "", "line": {"color": "#636efa", "dash": "solid"}, "mode": "lines", "name": "", "showlegend": false, "type": "scatter", "x": [1e-09, 2e-09, 3.0000000000000004e-09, 4e-09, 5e-09, 6e-09, 7.000000000000001e-09, 8e-09, 9.000000000000001e-09, 1.0000000000000002e-08, 1.1000000000000001e-08, 1.2000000000000002e-08, 1.3000000000000002e-08, 1.4000000000000001e-08, 1.5000000000000002e-08, 1.6e-08, 1.7e-08, 1.8e-08, 1.9e-08, 2e-08, 2.1e-08, 2.2000000000000002e-08, 2.3e-08, 2.4e-08, 2.5000000000000002e-08, 2.6e-08, 2.7e-08, 2.8e-08, 2.9e-08, 3.0000000000000004e-08, 3.1000000000000006e-08, 3.2e-08, 3.3000000000000004e-08, 3.4000000000000007e-08, 3.5e-08, 3.6000000000000005e-08, 3.700000000000001e-08, 3.8e-08, 3.9000000000000005e-08, 4.000000000000001e-08, 4.1e-08, 4.2000000000000006e-08, 4.300000000000001e-08, 4.4000000000000004e-08, 4.5000000000000006e-08, 4.600000000000001e-08, 4.7000000000000004e-08, 4.8000000000000006e-08, 4.900000000000001e-08, 5.0000000000000004e-08, 5.100000000000001e-08, 5.2e-08, 5.3000000000000005e-08, 5.400000000000001e-08, 5.5e-08, 5.6000000000000005e-08, 5.700000000000001e-08, 5.8e-08, 5.9000000000000006e-08, 6.000000000000001e-08, 6.1e-08, 6.2e-08, 6.3e-08, 6.4e-08, 6.5e-08, 6.6e-08, 6.7e-08, 6.8e-08, 6.9e-08, 7e-08, 7.1e-08, 7.2e-08, 7.3e-08, 7.4e-08, 7.5e-08, 7.6e-08, 7.7e-08, 7.8e-08, 7.9e-08, 8e-08, 8.1e-08, 8.2e-08, 8.3e-08, 8.4e-08, 8.500000000000001e-08, 8.6e-08, 8.7e-08, 8.800000000000001e-08, 8.9e-08, 9e-08, 9.100000000000001e-08, 9.2e-08, 9
07, 2.4600000000000006e-07, 2.4700000000000003e-07, 2.4800000000000005e-07, 2.49e-07, 2.5000000000000004e-07, 2.5100000000000006e-07, 2.5200000000000003e-07, 2.5300000000000006e-07, 2.54e-07, 2.5500000000000005e-07, 2.56e-07, 2.5700000000000004e-07, 2.5800000000000006e-07, 2.5900000000000003e-07, 2.6000000000000005e-07, 2.61e-07, 2.6200000000000004e-0 ...

# %% [markdown]
# # Raoult's Law

# %% [markdown]
# Over a a plane water surface, the reduction in vapor pressure due to the presence of a non-volatile solute is:

# %% [markdown]
# # $a_w=\frac{e'}{e_s(\infty)} = \frac{n_w}{n_w + n_s} = (1 + \frac{n_s}{n_w})^{-1} = 1 - \frac{n_s}{n_w}$
#
# $ e'=$ equilibrium vapor pressure over a solution
#
# $ e_s=$ equilibrium vapor pressure of pure water
#
# $ n_w=$ moles of water in the droplet
#
# $ n_s=$ moles of solute in the droplet
#
# If we assume $n_d << n_w$

# %% [markdown]
# Now we can define the moles of water (nw) and moles of solute (ns) inside the droplet:

# %% [markdown]
# # $ n_w = \frac{m_w}{M_{H2O}} = \frac{\frac{4}{3}\pi r^3 \rho_{H20}}{M_{H20}} $
#
# # $ n_s = \frac{m_s}{M_s}$

# %% [markdown]
# Here we have also assumed the density of the water is not changed due to the addition of solute.

# %% [markdown]
# Putting this all together, we get an equation for the water activity of a droplet in solution:

# %% [markdown]
# # $ a_w = 1 - \frac{3 M_{H20} m_s}{4 \pi M_s \rho_w r^3} = 1 - \frac{B}{r^3}$
#
# where
#
# # $ B = (\frac{3 M_{H20} m_s}{4 \pi M_s \rho_w }) $

# %% [markdown]
# If the equation above is multiplied on the right side by es, it gives the saturation vapor pressure of the solution.

# %% [markdown]
# # Koehler Curves

# %% [markdown]
# Here we define a new equilibrium saturation ratio, which is the saturation vapor pressure of the solution over the saturation vapor pressure of pure water, and is based on the combination of Raoult's law and Kelvin's equation. In this, we assume the surface tension of the solution is not changed from that of pure water:

# %% [markdown]
# # $ S_k = \frac{e'(n_s,r,T)}{e_s(T, \infty)} = (1 - \frac{B}{r^3}) (e^{\frac{A}{r}})$

# %% [markdown]
# If we multiply the right side of the above equation by es, we are left with the saturation vapor pressure of a droplet in solution:

# %% [markdown]
# # $ e'(n_s,r,T) = e_s(T, \infty) (1 - \frac{B}{r^3}) (e^{\frac{A}{r}})$

# %% [markdown]
# This can be plotted (but I don't want to right now. Come back to these two pages to make sure this is all correct: https://www2.physics.ox.ac.uk/sites/default/files/C5_PhysicsOfAtmospheresAndOceans_SectionA_Lecture3_WarmCloudMicrophysics.pdf
# http://kestrel.nmt.edu/~raymond/classes/ph536/notes/microphys.pdf

# %% [markdown]
# # Kappa Theory

# %% [markdown]
# Next we can go deeper by learning kappa-kohler theory. This is where important assumptions come into play.
